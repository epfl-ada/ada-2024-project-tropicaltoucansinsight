# %%
# Plot figures in the notebook (instead of a new window)
# %matplotlib notebook

# Automatically reload modules
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import src.utils.data_utils as data_utils

# %%
df_channel_music = pd.read_csv("/Volumes/Crucial X6 1/channels/Music_channels.csv", sep="\t")
print(df_channel_music.dtypes)
df_channel_music = data_utils.cast_df(df_channel_music, type='channel')
df_channel_music.head()
# Out:
# Unnamed: 0              int64
# category_cc            object
# join_date              object
# channel                object
# name_cc                object
# subscribers_cc          int64
# videos_cc               int64
# subscriber_rank_sb    float64
# weights               float64
# dtype: object
#    Unnamed: 0 category_cc  join_date                   channel  \
# 0           6       Music 2014-03-12  UCFFbwnve3yF62-tVXkTyHqg
# 1           9       Music 2006-08-08  UC0C-w0YjGpqDXGB8IHb662A
# 2          11       Music 2007-02-09  UCfM3zsQsOnfWNUppiycmBuw
# 3          12       Music 2007-01-22  UC9CoOnJkIBMdeijd9qYoT_g
# 4          13       Music 2006-09-20  UCqECaJ8Gagnn7YCbPEzWH6g
#
#              name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  weights
# 0  Zee Music Company        43451109       4241                13.0    2.087
# 1         Ed Sheeran        42000000        154                17.0    2.087
# ...

# %%
df_video_music = pd.read_parquet("/Volumes/Crucial X6/video_metadata/Shows.parquet")
df_video_music.head()
#df_video_music = data_utils.cast_videos_df(df_channel_music)
#data_utils.get_stats_on_channel_category(dyf_video_music, category_name="music", corr_method='spearman')
#plt.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_video_music = pd.read_parquet("/Volumes/Crucial X6/video_metadata/Shows.parquet")
#       2 df_video_music.head()
#       3 #df_video_music = data_utils.cast_videos_df(df_channel_music)
#       4 #data_utils.get_stats_on_channel_category(dyf_video_music, category_name="music", corr_method='spearman')
#       5 #plt.close()
#
# File /opt/miniconda3/envs/tropicaltoucansinsight/lib/python3.11/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
# ...

# %%
plt.close('all')

# %%
df_video_show = pd.read_parquet("/Volumes/Crucial X6 1/video_metadata/Shows.parquet")

# %%
casted_df = data_utils.cast_df(df_channel_music, type='channel')
data_utils.get_stats_on_category(casted_df, type='channel', category_name='Music')
# Out:
# Displaying statistics to study the YouTube channels in the category: Music
#
# The category Music consists of 24285 channels.
# The DataFrame occupies 5.60 MB.
#
# Descriptive statistics for the Music category:
#                               Type    count                           mean  \
# Unnamed: 0                   int32  24285.0                   69643.357999
# join_date           datetime64[ns]    24285  2012-07-19 12:41:53.551575040
# subscribers_cc               int32  24285.0                  292134.635948
# videos_cc                    int32  24285.0                     666.219518
# subscriber_rank_sb         float32  24285.0                   366227.21875
# weights                    float32  24285.0                       7.420398
# category_cc         string[python]      NaN                            NaN
# channel             string[python]      NaN                            NaN
# name_cc             string[python]      NaN                            NaN
#
# ...

# %%
casted_df = data_utils.cast_df(df_video_nonprofits, type='video')
data_utils.get_stats_on_category(casted_df, type='video', category_name='Nonprofit')
# Out:
# Displaying statistics to study the YouTube videos in the category: Nonprofit
#
# The category Nonprofit consists of 777449 videos.
# The DataFrame occupies 1183.05 MB.
#
# Descriptive statistics for the Nonprofit category:
#                          Type     count                           mean  \
# crawl_date     datetime64[ns]    777449  2019-11-09 04:56:46.137992704
# dislike_count         float32  733731.0                      19.561295
# duration                int32  777449.0                    1196.373879
# like_count            float32  733731.0                     331.114471
# upload_date    datetime64[ns]    777449  2016-02-26 01:13:35.635237888
# view_count            float64  777415.0                   23807.638058
# categories     string[python]       NaN                            NaN
# channel_id     string[python]       NaN                            NaN
# description    string[python]       NaN                            NaN
# ...

# %%
df_video_pet = pd.read_parquet("/Volumes/Crucial X6 1/video_metadata/Pets & Animals.parquet")
df_video_nonprofits = pd.read_parquet("/Volumes/Crucial X6 1/video_metadata/Nonprofits & Activism.parquet")
df_time_series =  pd.concat([df_video_nonprofits, df_video_pet], axis=0)

categories = ["Pets & Animals", "Nonprofits & Activism"]
data_utils.compare_distribution_across_categories(df_time_series,
                                                  columns=["duration"],
                                                  categories=categories,
                                                  x_logs=[True],
                                                  y_logs=[False],
                                                  kind="hist",
                                                  hue="categories")
# Out:
# <div id='7a534743-e1e0-4a31-992b-5e14b3dd85da'></div>

# %%
df_video_music = pd.read_parquet("/Volumes/Crucial X6 1/video_metadata/Music.parquet")

# %%
casted_df = data_utils.cast_df(df_video_music, type='video')
data_utils.get_stats_on_category(casted_df, type='video', category_name='Music')
# Out:
# Displaying statistics to study the YouTube videos in the category: Music
#
# The category Music consists of 8305003 videos.
# The DataFrame occupies 14568.39 MB.
#
# Descriptive statistics for the Music category:
#                          Type      count                           mean  \
# crawl_date     datetime64[ns]    8305003  2019-11-10 07:38:19.121897216
# dislike_count         float32  8197981.0                     108.778442
# duration                int32  8305003.0                     471.251079
# like_count            float64  8197981.0                    2350.635442
# upload_date    datetime64[ns]    8305003  2016-05-31 16:32:47.446755328
# view_count            float64  8304989.0                  298012.099444
# categories     string[python]        NaN                            NaN
# channel_id     string[python]        NaN                            NaN
# description    string[python]        NaN                            NaN
# ...
