# %%
# Plot figures in the notebook (instead of a new window)
# %matplotlib notebook

# Automatically reload modules
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import src.utils.data_utils as data_utils
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_channel_music = pd.read_csv("/Volumes/Crucial X6/channels/Music_channels.csv", sep="\t")
print(df_channel_music.dtypes)
df_channel_music = data_utils.cast_channels_df(df_channel_music)
df_channel_music.head()
# Out:
# Unnamed: 0              int64
# category_cc            object
# join_date              object
# channel                object
# name_cc                object
# subscribers_cc          int64
# videos_cc               int64
# subscriber_rank_sb    float64
# weights               float64
# dtype: object
#    Unnamed: 0 category_cc  join_date                   channel  \
# 0           6       Music 2014-03-12  UCFFbwnve3yF62-tVXkTyHqg
# 1           9       Music 2006-08-08  UC0C-w0YjGpqDXGB8IHb662A
# 2          11       Music 2007-02-09  UCfM3zsQsOnfWNUppiycmBuw
# 3          12       Music 2007-01-22  UC9CoOnJkIBMdeijd9qYoT_g
# 4          13       Music 2006-09-20  UCqECaJ8Gagnn7YCbPEzWH6g
#
#              name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  weights
# 0  Zee Music Company        43451109       4241                13.0    2.087
# 1         Ed Sheeran        42000000        154                17.0    2.087
# ...

# %%
df_video_music = pd.read_parquet("/Volumes/Crucial X6/video_metadata/Shows.parquet")
df_video_music.head()
#df_video_music = data_utils.cast_videos_df(df_channel_music)
#data_utils.get_stats_on_channel_category(df_video_music, category_name="music", corr_method='spearman')
#plt.close()
# Out:
#   categories                channel_id                  crawl_date  \
# 0      Shows  UCVi2lI40LetxLBKn-rtWC3A  2019-11-04 09:46:53.370869
# 1      Shows  UCVi2lI40LetxLBKn-rtWC3A  2019-11-04 09:46:00.825118
# 2      Shows  UCVi2lI40LetxLBKn-rtWC3A  2019-11-04 09:45:54.760137
# 3      Shows  UCVi2lI40LetxLBKn-rtWC3A  2019-11-04 09:45:57.064612
# 4      Shows  UCVi2lI40LetxLBKn-rtWC3A  2019-11-04 09:45:59.381143
#
#                                          description  dislike_count  \
# 0  http://www.funimation.com/kamisama-kiss\n\nAba...            293
# 1  Available on Blu-Ray/DVD Combo 12/18/12\nhttp:...             27
# 2  Available on Blu-Ray/DVD Combo 12/18/12\nhttp:...             13
# 3  Available on Blu-Ray/DVD Combo 12/18/12\nhttp:...             14
# 4  Available on Blu-Ray/DVD Combo 12/18/12\nhttp:...             14
#
#     display_id  duration  like_count  \
# 0  RGTIpnn7tKQ      1441       15358
# 1  45N75Qb-BtU      1470         822
# ...

# %%
plt.close('all')

# %%
casted_df = data_utils.cast_videos_df(df_video_music)

# %%
print(df_video_music.dtypes)
print('\n')
print(casted_df.dtypes)
# Out:
# categories       object
# channel_id       object
# crawl_date       object
# description      object
# dislike_count     int64
# display_id       object
# duration          int64
# like_count        int64
# tags             object
# title            object
# upload_date      object
# view_count        int64
# dtype: object
#
#
# categories       string[python]
# channel_id       string[python]
# crawl_date       datetime64[ns]
# description      string[python]
# dislike_count             int16
# display_id       string[python]
# duration                  int16
# like_count                int16
# tags             string[python]
# title            string[python]
# upload_date      datetime64[ns]
# view_count                int32
# dtype: object

# %%
data_utils.get_stats_on_video_category(casted_df, 'shows')
# Out:
# Displaying statistics to study the YouTube videos in the category: shows
#
# The category shows consists of 41 videos.
# The DataFrame occupies 0.03 MB.
#
# Descriptive statistics for the shows category:
#                          Type count                           mean  \
# crawl_date     datetime64[ns]    41  2019-11-04 09:45:47.789550592
# dislike_count           int16  41.0                      16.780488
# duration                int16  41.0                    1435.390244
# like_count              int16  41.0                     710.585366
# upload_date    datetime64[ns]    41  2012-10-08 13:27:48.292683008
# view_count              int32  41.0                   76007.585366
# categories     string[python]   NaN                            NaN
# channel_id     string[python]   NaN                            NaN
# description    string[python]   NaN                            NaN
# display_id     string[python]   NaN                            NaN
# ...
